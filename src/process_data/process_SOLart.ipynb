# %%
import pandas as pd

# %%
df_s1_sheet1 = pd.read_excel("../../raw_data/SOLart/s1.xlsx", sheet_name="447_evaluated_proteins")
df_s1_sheet1.head(5)
# Out:
#   Accession    Name      SGD ID UniProt Entry  \
# 0   YBL016W    FUS3  S000000112        P16892
# 1   YBL019W    APN2  S000000115        P38207
# 2   YBL027W  RPL19B  S000000123        P0CX83
# 3   YBL032W    HEK2  S000000128        P38199
# 4   YBL039C    URA7  S000000135        P28274
#
#                                    Description  Solubility 37  \
# 0        Mitogen-activated protein kinase FUS3            2.6
# 1  DNA-(apurinic or apyrimidinic site) lyase 2           23.9
# 2                  60S ribosomal protein L19-B           61.3
# 3   Heterogeneous nuclear rnp K-like protein 2           57.4
# 4                               CTP synthase 1           79.2
#
#    Synthetic Yield 37 (mM)  Synthetic Yield 37 (mg/mL)  Solubility 30  \
# 0                   0.1270                         5.2           9.16
# 1                   0.0228                         1.4          13.20
# 2                   0.1888                         4.1          42.20
# ...

# %%
df_s1_sheet1 = df_s1_sheet1[["Accession", "UniProt Entry", "Solubility 37", "Solubility 30"]]
df_s1_sheet1.shape
# Out:
# (447, 4)

# %%
df_s1_sheet1
